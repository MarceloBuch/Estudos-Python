# %% [markdown]
# <h2>Exemplo de árvore de decisão</h2>

# %%
from sklearn.datasets import load_iris
from sklearn import tree
from sklearn.model_selection import train_test_split
import pandas as pd
import sklearn.metrics as metrics

# %% [markdown]
# <h3>importando dados do dataset Iris</h3>

# %%
iris = load_iris()
print(iris['DESCR'])

# %% [markdown]
# <h3>Estipulando partes de teste e treino</h3>

# %%
X_train, X_test, y_train, y_test = train_test_split(iris.data, iris.target, test_size=0.25)

# %% [markdown]
# <h3>Aplicando o método para a criação da árvore</h3>

# %%
clf = tree.DecisionTreeClassifier(criterion='entropy') #quando entropia é igual a zero significa que a arvore encontrou uma predição para os testes
clf = clf.fit(X_train, y_train)
predictions = clf.predict(X_test)

# %% [markdown]
# <h3>Apresentando matriz de confusão juntamente com o relatório de qualidade dos resultados gerados</h3>

# %%
print('\n Matriz de confusão\n', pd.crosstab(y_test, predictions, rownames=['Real'], colnames=['Predito'], margins = True, margins_name="Todos"))
# Out:
#  Matriz de confusão
#  Predito   0  1   2  Todos
# Real
# 0        17  0   0     17
# 1         0  9   0      9
# 2         0  0  12     12
# Todos    17  9  12     38

# %%
print('Relatório sobre a qualidade: \n')
print(metrics.classification_report(y_test, predictions, target_names = ['Setosa', 'Versicolor', 'Virginica']))
# Out:
# Relatório sobre a qualidade:
#
#               precision    recall  f1-score   support
#
#       Setosa       1.00      1.00      1.00        17
#   Versicolor       1.00      1.00      1.00         9
#    Virginica       1.00      1.00      1.00        12
#
#     accuracy                           1.00        38
#    macro avg       1.00      1.00      1.00        38
# weighted avg       1.00      1.00      1.00        38
